# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("retail_sales_dataset.csv")

# %%
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Transaction ID      1000
# Date                 345
# Customer ID         1000
# Gender                 2
# Age                   47
# Product Category       3
# Quantity               4
# Price per Unit         5
# Total Amount          18
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df['Age']=df['Age'].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int32
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int32(1), int64(4), object(4)
# memory usage: 66.5+ KB

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
plt.figure(figsize=(4,4))
plt.bar(x="Gender",height="Total Amount",data=df)
plt.xlabel("Gender")
plt.ylabel("Total amount")
plt.title("Gender vs Total Amount")
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.barplot(x="Gender",y="Total Amount",hue="Product Category",data=df)
plt.title("Total Amount of Gender")
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.hist(x="Total Amount",data=df)
plt.xlabel("Total Amount")
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x="Gender",y="Price per Unit",hue="Product Category",data=df)
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
df['Gender'].value_counts().plot.pie(autopct="%1.1f%%",explode=[0.1,0.1])
plt.show()

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x="Product Category",data=df)
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.kdeplot(x="Total Amount",data=df)
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.histplot(x="Quantity",data=df)
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.boxplot(x="Total Amount",data=df)
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.boxplot(x="Age",hue="Product Category",data=df)
plt.show()

# %%
num_feature=[i for i in df if df[i].dtype !="object"]
num_feature
# Out:
# ['Transaction ID', 'Age', 'Quantity', 'Price per Unit', 'Total Amount']

# %%
df[num_feature].corr()
# Out:
#                 Transaction ID       Age  Quantity  Price per Unit  \
# Transaction ID        1.000000  0.065191 -0.026623       -0.060837
# Age                   0.065191  1.000000 -0.023737       -0.038423
# Quantity             -0.026623 -0.023737  1.000000        0.017501
# Price per Unit       -0.060837 -0.038423  0.017501        1.000000
# Total Amount         -0.075034 -0.060568  0.373707        0.851925
#
#                 Total Amount
# Transaction ID     -0.075034
# Age                -0.060568
# Quantity            0.373707
# Price per Unit      0.851925
# Total Amount        1.000000

# %%
sns.heatmap(df[num_feature].corr(),annot=True,cmap="PiYG")
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# #Retail Sales Analysis Summary
#
# 1.Data Preparation: Load, clean, and preprocess sales data (handling missing values, formatting dates, calculating revenue).
#
# 2.KPIs: Compute total revenue, average order value, customer count, top-selling products, and categories.
#
# 3.Trends & Patterns: Analyze sales over time to identify peak sales periods, and customer buying behavior.
#
# 4.Visualizations: Use line charts for trends, bar charts for product/category performance, heatmaps for time-based sales patterns.
#
# 5.Advanced Analysis: Perform customer segmentation (RFM), basket analysis (frequently bought together), and forecasting (time series models).
#
# 6.Insights: Discover top revenue drivers, seasonal effects, customer retention patterns, and future sales expectations.
